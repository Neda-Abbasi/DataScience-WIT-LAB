# %% [markdown]
# <a href="https://colab.research.google.com/github/Neda-Abbasi/DataScience-WIT-LAB/blob/main/WidsDatathonCH_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a92fe785-0a38-4754-8c86-5ef3a6407f92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a92fe785-0a38-4754-8c86-5ef3a6407f92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c widsdatathon2024-challenge2
# Out:
# ...
#   0% 0.00/5.71M [00:00<?, ?B/s]
# 100% 5.71M/5.71M [00:00<00:00, 101MB/s]

# %%
# !unzip widsdatathon2024-challenge2.zip
# !ls
# Out:
# Archive:  widsdatathon2024-challenge2.zip
#   inflating: solution_template.csv
#   inflating: test.csv
#   inflating: train.csv
# kaggle.json  solution_template.csv  train.csv
# sample_data  test.csv		    widsdatathon2024-challenge2.zip

# %%
train = pd.read_csv('/content/train.csv')
train
# Out:
#        patient_id patient_race  payer_type patient_state  patient_zip3  \
# 0          268700          NaN  COMMERCIAL            AR           724
# 1          484983        White         NaN            IL           629
# 2          277055          NaN  COMMERCIAL            CA           925
# 3          320055     Hispanic    MEDICAID            CA           900
# 4          190386          NaN  COMMERCIAL            CA           934
# ...           ...          ...         ...           ...           ...
# 13168      588544     Hispanic    MEDICAID            PA           191
# 13169      393047          NaN  COMMERCIAL            TX           757
# 13170      790904          NaN  COMMERCIAL            CA           928
# 13171      455518          NaN  COMMERCIAL            MI           481
# 13172      379418     Hispanic    MEDICAID            CA           900
#
#           Region            Division  patient_age patient_gender    bmi  ...  \
# ...

# %% [markdown]
# Task #1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13173 entries, 0 to 13172
# Columns: 152 entries, patient_id to metastatic_diagnosis_period
# dtypes: float64(137), int64(4), object(11)
# memory usage: 15.3+ MB

# %% [markdown]
# Task #2

# %%
train.describe()
# Out:
#           patient_id  patient_zip3   patient_age          bmi    population  \
# count   13173.000000  13173.000000  13173.000000  4102.000000  13173.000000
# mean   555441.784939    568.530859     59.271313    29.168808  20651.373928
# std    259476.503094    275.758485     13.218883     5.752820  13840.379638
# min    100043.000000    100.000000     18.000000    15.000000    635.550000
# 25%    335100.000000    330.000000     50.000000    24.825000   9160.340000
# 50%    555769.000000    557.000000     59.000000    28.580000  18952.780000
# 75%    780967.000000    832.000000     67.000000    33.000000  30021.280000
# max    999982.000000    995.000000     91.000000    97.000000  71374.130000
#
#             density    age_median  age_under_10  age_10_to_19       age_20s  \
# count  13173.000000  13173.000000  13173.000000  13173.000000  13173.000000
# mean    1776.872376     40.542676     11.104988     12.857587     13.297375
# ...

# %%
train.describe(include=['object'])
# Out:
#        patient_race  payer_type patient_state Region            Division  \
# count          6516       11408         13173  13173               13173
# unique            5           3            44      4                   8
# top           White  COMMERCIAL            CA  South  East North Central
# freq           3565        6297          2377   3960                3010
#
#        patient_gender breast_cancer_diagnosis_code  \
# count           13173                        13173
# unique              1                           47
# top                 F                         1749
# freq            13173                         1947
#
#                              breast_cancer_diagnosis_desc  \
# count                                               13173
# unique                                                 47
# top     Malignant neoplasm of breast (female), unspeci...
# freq                                                 1947
#
# ...

# %% [markdown]
# Task #3

# %%
train.isnull()
# Out:
#        patient_id  patient_race  payer_type  patient_state  patient_zip3  \
# 0           False          True       False          False         False
# 1           False         False        True          False         False
# 2           False          True       False          False         False
# 3           False         False       False          False         False
# 4           False          True       False          False         False
# ...           ...           ...         ...            ...           ...
# 13168       False         False       False          False         False
# 13169       False          True       False          False         False
# 13170       False          True       False          False         False
# 13171       False          True       False          False         False
# 13172       False         False       False          False         False
#
#        Region  Division  patient_age  patient_gender    bmi  ...  \
# ...

# %%
train.isnull().any()
# Out:
# patient_id                     False
# patient_race                    True
# payer_type                      True
# patient_state                  False
# patient_zip3                   False
#                                ...
# Average of Sep-18               True
# Average of Oct-18               True
# Average of Nov-18               True
# Average of Dec-18               True
# metastatic_diagnosis_period    False
# Length: 152, dtype: bool

# %%
train.isnull().sum()
# Out:
# patient_id                        0
# patient_race                   6657
# payer_type                     1765
# patient_state                     0
# patient_zip3                      0
#                                ...
# Average of Sep-18                 7
# Average of Oct-18                 7
# Average of Nov-18                12
# Average of Dec-18                33
# metastatic_diagnosis_period       0
# Length: 152, dtype: int64
